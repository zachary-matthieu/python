# %%
import matplotlib.pyplot as plt

# %%
# Sample data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
traffic = [150, 200, 180, 220, 250, 210]

# %%
# Create Line Plot
plt.plot(months, traffic)
plt.show()

# %%
# Labels
plt.plot(months, traffic)

plt.xlabel('Month')
plt.ylabel('Monthly Traffic (thousands)')
plt.title('Monthly Website Traffic')

plt.show()

# %%
# Customize Plot
plt.plot(months, traffic, marker = 'o', linestyle = '--', color = 'g')

plt.xlabel('Month')
plt.ylabel('Monthly Traffic (thousands)')
plt.title('Monthly Website Traffic')

plt.show()

# %%
# Style Plot Options 
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Style Plot
plt.plot(months, traffic, marker = 'o', linestyle = '--', color = 'g')

plt.xlabel('Month')
plt.ylabel('Monthly Traffic (thousands)')
plt.title('Monthly Website Traffic')

plt.style.use('Solarize_Light2')

plt.show()

# %%
# More Sample Data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
product_a_revenue = [45, 55, 60, 70, 80, 75]
product_b_revenue = [35, 40, 50, 55, 70, 68]

# %%
# Multiple Line Plots 
plt.plot(months, product_a_revenue, marker = 'o', linestyle = '-', color = 'blue', label = 'Product A')
plt.plot(months, product_b_revenue, marker = 's', linestyle = '--', color = 'red', label = 'Product B')

plt.xlabel('Month')
plt.ylabel('Monthly Revenue ($1000)')
plt.title('Monthly Revenue Comparison')

plt.style.use('seaborn-bright')

# Plot Legend
plt.legend()

plt.show()

# %%
# Import NumPy
import numpy as np

# Bar Charts
categories = ['Housing', 'Transportation', 'Food', 'Entertainment', 'Utilities']
alice_expenses = [1200, 300, 400, 200, 150]
bob_expenses = [1100, 320, 380, 180, 140]
carol_expenses = [1300, 280, 420, 220, 160]

# Array for X-Axis
x = np.arange(len(categories))

# Plot Width
bar_width = 0.2

# X-Axis Allocation 
plt.bar(x - bar_width, alice_expenses, width = bar_width, label = 'Alice', color = 'skyblue')
plt.bar(x, bob_expenses, width = bar_width, label = 'Bob', color = 'lightcoral')
plt.bar(x + bar_width, carol_expenses, width = bar_width, label = 'Carol', color = 'lightgreen')

plt.xlabel('Expense Categories')
plt.ylabel('Monthly Expense (USD)')
plt.title('Monthly Expense Comparison')

# Fixing Categories to X-Axis
plt.xticks(x, categories)

plt.legend()

plt.show()

# %%
# Histograms
exam_scores = [68, 72, 75, 80, 82, 84, 86, 90, 92, 95, 98, 100]

# Bin Ranges
bin_ranges = [60, 70, 80, 90, 100]

plt.hist(exam_scores, bins = bin_ranges, color = 'lightblue', edgecolor = 'black', alph = 0.7)

plt.xlabel('Exam Scores')
plt.ylabel('Frequency')
plt.title('Exam Scores Histogram with Custom Bins')

# Calculate Median line
median_score = np.median(exam_scores)
plt.axvline(median_score, color = 'red', linestyle = 'dashed', linewidth = 2, label = 'Median Score: {median_score}')

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14956\4089012504.py in <module>
#       5 bin_ranges = [60, 70, 80, 90, 100]
#       6
# ----> 7 plt.hist(exam_scores, bins = bin_ranges, color = 'lightblue', edgecolor = 'black', alph = 0.7)
#       8
#       9 plt.xlabel('Exam Scores')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2600         orientation='vertical', rwidth=None, log=False, color=None,
#    2601         label=None, stacked=False, *, data=None, **kwargs):
# -> 2602     return gca().hist(
#    2603         x, bins=bins, range=range, density=density, weights=weights,
#    2604         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6785             if patch:
#    6786                 p = patch[0]
# -> 6787                 p.update(kwargs)
#    6788                 if lbl is not None:
#    6789                     p.set_label(lbl)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'alph'

# %%
# Scatter Plots
stores = ['Store A', 'Store B', 'Store C', 'Store D', 'Store E']
customers = [120, 90, 150, 80, 200]
revenue = [20000, 18000, 25000, 17000, 30000]
store_size = [10, 5, 15, 8, 20] 

# Scaling Point Sizes
point_sizes = [size * 100 for size in store_size]

plt.scatter(customers, revenue, s = point_sizes, c = 'skyblue', alpha = 0.7, edgecolors = 'b')

plt.xlabel('Number of Customers')
plt.ylabel('Revenue (USD)')
plt.title('Relationship between Customers, Revenue, and Store Size')

plt.show()

# %%
# Pie Charts
categories = ['Electronics', 'Clothing', 'Home Decor', 'Books', 'Toys']
sales = [3500, 2800, 2000, 1500, 1200]

# Explode Slice
explode = (0, 0.1, 0, 0, 0) 

plt.pie(sales, labels = categories, explode = explode, shadow = True, autopct = '%1.1f%%')
plt.title('Sales by Product Category')

plt.show()

# %%
# Box and Whiskers Plot

# Generate Random with Ouliers
np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 100), np.random.normal(6, 1, 10)])

# Figure Size
plt.figure(figsize=(8, 6)) 

plt.boxplot(data, vert=False, patch_artist=True, boxprops={'facecolor': 'lightblue'}, flierprops = {'marker': 'o', 'markerfacecolor': 'red', 'markeredgecolor': 'red'})

plt.xlabel('Values')
plt.title('Box Plot with Outliers')

# Readability Grid
plt.grid(True) 

plt.show()

# %%
# Heat Map
# Correlation Matrix
correlation_matrix = np.array(
[[1.0, 0.8, 0.3, -0.2],
[0.8, 1.0, 0.5, 0.1],
[0.3, 0.5, 1.0, -0.4],
[-0.2, 0.1, -0.4, 1.0]])

plt.imshow(correlation_matrix, cmap ='coolwarm', vmin = -1, vmax = 1, aspect = 'auto', origin = 'upper')

# Color Bar
cbar = plt.colorbar()
cbar.set_label('Correlation', rotation = 270, labelpad = 20)

plt.title('Correlation Matrix Heatmap')
plt.xticks(range(len(correlation_matrix)), ['Var1', 'Var2', 'Var3', 'Var4'])
plt.yticks(range(len(correlation_matrix)), ['Var1', 'Var2', 'Var3', 'Var4'])

plt.show()

# %%
# Stack Plots
quarters = ['Q1', 'Q2', 'Q3', 'Q4']
electronics = [10000, 12000, 11000, 10500]
clothing = [5000, 6000, 7500, 8000]
home_appliances = [7000, 7500, 8200, 9000]

plt.figure(figsize = (10, 6)) 

plt.stackplot(quarters, electronics, clothing, home_appliances, labels = ['Electronics', 'Clothing', 'Home Appliances'], colors = ['blue', 'green', 'red'], alpha = 0.7)

plt.xlabel('Quarters')
plt.ylabel('Sales ($)')
plt.title('Product Category Sales Over Quarters')
plt.legend(loc = 'upper left')

plt.grid(True)

plt.show()
