# %%
import pandas as pd

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv(r'C:\Users\zacha\Hyperborea\csv files\survey_results_public.csv')

# %%
df.head(5)
# Out:
#                                                    MainBranch  \
# Respondent
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# Respondent
# 1                                                    Slovakia      NaN
# ...

# %%
df.rename(columns = {'ResponseId': 'Respondent', 'ConvertedCompYearly': 'Salary'}, inplace = True)

# %%
df.set_index(['Respondent'], inplace = True)

# %%
df['Country'] = df['Country'].replace(['United States of America'], 'America')

# %% [markdown]
# # Start

# %%
# DataFrame + Description 

df.describe()
# Out:
#           CompTotal        Salary
# count  4.718300e+04  4.684400e+04
# mean   2.119407e+69  1.184262e+05
# std    4.603702e+71  5.272944e+05
# min    0.000000e+00  1.000000e+00
# 25%    1.600000e+04  2.702500e+04
# 50%    6.700000e+04  5.621100e+04
# 75%    1.400000e+05  1.000000e+05
# max    1.000000e+74  4.524131e+07

# %%
# Column + Median 

df['Salary'].median()
# Out:
# 56211.0

# %%
# Column + Average 

df['Salary'].mean()
# Out:
# 118426.15289044488

# %%
# Column + Count 

df['Salary'].count()
# Out:
# 46844

# %%
# Column + Value Count

df['Country'].value_counts()
# Out:
# America                                                 15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
# Column + Value Count + Percentage 

df['Country'].value_counts(normalize = True)
# Out:
# America                                                 0.183224
# India                                                   0.125972
# Germany                                                 0.067415
# United Kingdom of Great Britain and Northern Ireland    0.053632
# Canada                                                  0.036098
#                                                           ...
# Saint Kitts and Nevis                                   0.000012
# Dominica                                                0.000012
# Saint Vincent and the Grenadines                        0.000012
# Tuvalu                                                  0.000012
# Papua New Guinea                                        0.000012
# Name: Country, Length: 181, dtype: float64

# %%
df['Employment'].value_counts(normalize = True)
# Out:
# Employed full-time                                      0.643088
# Student, full-time                                      0.141390
# Independent contractor, freelancer, or self-employed    0.096504
# Not employed, but looking for work                      0.035536
# Employed part-time                                      0.029536
# Student, part-time                                      0.024615
# Not employed, and not looking for work                  0.014738
# I prefer not to say                                     0.010681
# Retired                                                 0.003912
# Name: Employment, dtype: float64

# %%
# Create a Groupby

country_group = df.groupby(['Country'])

# %%
# Groupby + Value 

country_group.get_group('America')
# Out:
#                                         MainBranch  \
# Respondent
# 6           I am a student who is learning to code
# 7                      I code primarily as a hobby
# 16          I am a student who is learning to code
# 37                  I am a developer by profession
# 38                  I am a developer by profession
# ...                                            ...
# 83428               I am a developer by profession
# 83430                  I code primarily as a hobby
# 83431               I am a developer by profession
# 83435               I am a developer by profession
# 83437               I am a developer by profession
#
#                                     Employment  Country              US_State  \
# Respondent
# 6                           Student, part-time  America               Georgia
# 7                          I prefer not to say  America         New Hampshire
# 16                          Student, full-time  America              Missouri
# ...

# %%
# Filter  

usa_filt = df['Country'] == 'America'

df.loc[usa_filt]
# Out:
#                                         MainBranch  \
# Respondent
# 6           I am a student who is learning to code
# 7                      I code primarily as a hobby
# 16          I am a student who is learning to code
# 37                  I am a developer by profession
# 38                  I am a developer by profession
# ...                                            ...
# 83428               I am a developer by profession
# 83430                  I code primarily as a hobby
# 83431               I am a developer by profession
# 83435               I am a developer by profession
# 83437               I am a developer by profession
#
#                                     Employment  Country              US_State  \
# Respondent
# 6                           Student, part-time  America               Georgia
# 7                          I prefer not to say  America         New Hampshire
# 16                          Student, full-time  America              Missouri
# ...

# %%
# Loc + Filter + Value Count 

df.loc[usa_filt]['Employment'].value_counts()
# Out:
# Employed full-time                                      11214
# Student, full-time                                       1689
# Independent contractor, freelancer, or self-employed      976
# Not employed, but looking for work                        425
# Employed part-time                                        263
# Not employed, and not looking for work                    244
# I prefer not to say                                       185
# Student, part-time                                        140
# Retired                                                   130
# Name: Employment, dtype: int64

# %%
# Filter + Value Count By Percentage 

df.loc[usa_filt]['Employment'].value_counts(normalize = True)
# Out:
# Employed full-time                                      0.734574
# Student, full-time                                      0.110638
# Independent contractor, freelancer, or self-employed    0.063933
# Not employed, but looking for work                      0.027840
# Employed part-time                                      0.017228
# Not employed, and not looking for work                  0.015983
# I prefer not to say                                     0.012118
# Student, part-time                                      0.009171
# Retired                                                 0.008516
# Name: Employment, dtype: float64

# %%
# Groupby + Value Count 

country_group['Employment'].value_counts()
# Out:
# Country      Employment
# Afghanistan  Employed full-time                                      19
#              I prefer not to say                                     10
#              Student, full-time                                       7
#              Employed part-time                                       6
#              Student, part-time                                       6
#                                                                      ..
# Zimbabwe     Independent contractor, freelancer, or self-employed     4
#              Not employed, but looking for work                       4
#              I prefer not to say                                      2
#              Not employed, and not looking for work                   2
#              Student, part-time                                       2
# Name: Employment, Length: 1122, dtype: int64

# %%
# Groupby + Value Count + Head 

country_group['Employment'].value_counts().head(25)
# Out:
# Country      Employment
# Afghanistan  Employed full-time                                      19
#              I prefer not to say                                     10
#              Student, full-time                                       7
#              Employed part-time                                       6
#              Student, part-time                                       6
#              Independent contractor, freelancer, or self-employed     5
#              Not employed, but looking for work                       4
#              Retired                                                  4
#              Not employed, and not looking for work                   3
# Albania      Employed full-time                                      43
#              Independent contractor, freelancer, or self-employed     7
#              Not employed, and not looking for work                   5
#              Student, full-time                                       5
# ...

# %%
# Groupby + Column + Value Count + Loc + Value 

country_group['Employment'].value_counts().loc['China']
# Out:
# Employment
# Employed full-time                                      650
# Student, full-time                                      226
# Student, part-time                                       52
# Independent contractor, freelancer, or self-employed     32
# Not employed, but looking for work                       32
# Employed part-time                                       24
# Not employed, and not looking for work                   22
# I prefer not to say                                      13
# Retired                                                   1
# Name: Employment, dtype: int64

# %%
# Groupby + Value Count + Percentage + Loc + Value 

country_group['Employment'].value_counts(normalize = True).loc['China']
# Out:
# Employment
# Employed full-time                                      0.617871
# Student, full-time                                      0.214829
# Student, part-time                                      0.049430
# Independent contractor, freelancer, or self-employed    0.030418
# Not employed, but looking for work                      0.030418
# Employed part-time                                      0.022814
# Not employed, and not looking for work                  0.020913
# I prefer not to say                                     0.012357
# Retired                                                 0.000951
# Name: Employment, dtype: float64

# %%
race_group = df.groupby('Ethnicity')

race_group.get_group('White').head(5)
# Out:
#                                         MainBranch  \
# Respondent
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
# 4                   I am a developer by profession
# 5                   I am a developer by profession
# 10                  I am a developer by profession
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
# 10                                         Employed full-time
#
#                                                       Country US_State  \
# Respondent
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# ...

# %%
df['Ethnicity'] = df['Ethnicity'].replace(['White or of European descent'], 'White')

# %%
white_filt = df['Ethnicity'] == 'White'

df.loc[white_filt]['Ethnicity'].value_counts()
# Out:
# White    42671
# Name: Ethnicity, dtype: int64

# %%
# Groupby + Column + Mean + Value Counts 

country_group['Salary'].mean().sort_values(ascending = False)
# Out:
# Country
# Afghanistan                          2794748.000
# San Marino                            596700.000
# America                               262993.898
# North Korea                           240000.000
# Nomadic                               215491.278
#                                          ...
# Mali                                         NaN
# Micronesia, Federated States of...           NaN
# Papua New Guinea                             NaN
# Sierra Leone                                 NaN
# Tuvalu                                       NaN
# Name: Salary, Length: 181, dtype: float64

# %%
# Groupby + Column + Mean + Value 

country_group['Salary'].mean().loc['China']
# Out:
# 62562.90969899666

# %%
# Median + Mean = Agg Function 

country_group['Salary'].agg(['median', 'mean']).loc['China']
# Out:
# median   34296.000
# mean     62562.910
# Name: China, dtype: float64

# %%
# Groupby + Column + Apply + Lambda + Str + Sum 

country_group['Gender'].apply(lambda x: x.str.contains('Man').sum())
# Out:
# Country
# Afghanistan                                38
# Albania                                    56
# Algeria                                    41
# America                                 13337
# Andorra                                     8
#                                         ...
# Venezuela, Bolivarian Republic of...       99
# Viet Nam                                  351
# Yemen                                      18
# Zambia                                     21
# Zimbabwe                                   33
# Name: Gender, Length: 181, dtype: int64

# %%
df[usa_filt]['Gender'].value_counts()
# Out:
# Man                                                                                   13185
# Woman                                                                                   908
# Prefer not to say                                                                       346
# Non-binary, genderqueer, or gender non-conforming                                       217
# Or, in your own words:                                                                   92
# Man;Non-binary, genderqueer, or gender non-conforming                                    89
# Woman;Non-binary, genderqueer, or gender non-conforming                                  65
# Man;Or, in your own words:                                                               50
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                  7
# Woman;Or, in your own words:                                                              7
# ...

# %%
afghan_filt = df['Country'] == 'Afghanistan'

# %%
df[afghan_filt]['Gender'].value_counts()
# Out:
# Man                                                                                   36
# Or, in your own words:                                                                 5
# Non-binary, genderqueer, or gender non-conforming                                      5
# Woman                                                                                  4
# Prefer not to say                                                                      3
# Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:     1
# Man;Non-binary, genderqueer, or gender non-conforming                                  1
# Name: Gender, dtype: int64
